# %%
import pandas as pd
import numpy as np
from pathlib import Path
from src.utils import basic_test_data_cleaning

# %%
root = Path.cwd().parent
test_path = root/"data"/"raw"/"test.csv"
test_df = pd.read_csv(test_path)

# %%
test_df
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x2318    COIMBRES13DEL01                 NaN                     NaN
# 1      0x3474     BANGRES15DEL01                   28                     4.6
# 2      0x9420      JAPRES09DEL03                   23                     4.5
# 3      0x72ee      JAPRES07DEL03                   21                     4.8
# 4      0xa759     CHENRES19DEL01                   31                     4.6
# ...        ...                ...                 ...                     ...
# 11394  0x6909      JAPRES01DEL01                   35                     4.6
# 11395  0x443b      JAPRES11DEL01                   33                     4.9
# 11396  0x1ea5      SURRES11DEL03                 NaN                     NaN
# 11397  0x22d4      VADRES03DEL02                   27                     4.7
# 11398  0xb7be     CHENRES07DEL02                   39                       5
#
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11399 entries, 0 to 11398
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           11399 non-null  object
#  1   Delivery_person_ID           11399 non-null  object
#  2   Delivery_person_Age          11399 non-null  object
#  3   Delivery_person_Ratings      11399 non-null  object
#  4   Restaurant_latitude          11399 non-null  float64
#  5   Restaurant_longitude         11399 non-null  float64
#  6   Delivery_location_latitude   11399 non-null  float64
#  7   Delivery_location_longitude  11399 non-null  float64
#  8   Order_Date                   11399 non-null  object
#  9   Time_Orderd                  11399 non-null  object
#  10  Time_Order_picked            11399 non-null  object
#  11  Weatherconditions            11399 non-null  object
# ...

# %%
pd.to_datetime(test_df['Order_Date'],dayfirst=True)
# Out:
# 0       2022-03-30
# 1       2022-03-29
# 2       2022-03-10
# 3       2022-04-02
# 4       2022-03-27
#            ...
# 11394   2022-03-27
# 11395   2022-03-11
# 11396   2022-03-11
# 11397   2022-03-06
# 11398   2022-03-24
# Name: Order_Date, Length: 11399, dtype: datetime64[ns]

# %%
test_df[test_df['Order_Date']=="17-02-2022"]
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 10     0xd845      KOCRES09DEL01                   24                     4.8
# 74     0xcb17      ALHRES06DEL02                   25                     4.9
# 103    0xc500      AGRRES08DEL02                   35                     4.9
# 148    0xd9b5      AGRRES02DEL01                   29                     4.6
# 153    0xc94a      DEHRES17DEL02                   31                     4.7
# ...        ...                ...                 ...                     ...
# 11184  0xc812      BHPRES09DEL01                   28                     4.7
# 11198  0xd048      ALHRES03DEL01                   25                     4.8
# 11267  0xc1a9      ALHRES19DEL01                   30                       5
# 11313  0xd69f      KOLRES02DEL02                   27                     4.7
# 11321  0xd1dc     LUDHRES19DEL02                   37                     4.7
#
# ...

# %%
test_df['Order_Date']
# Out:
# 0        30-03-2022
# 1        29-03-2022
# 2        10-03-2022
# 3        02-04-2022
# 4        27-03-2022
#             ...
# 11394    27-03-2022
# 11395    11-03-2022
# 11396    11-03-2022
# 11397    06-03-2022
# 11398    24-03-2022
# Name: Order_Date, Length: 11399, dtype: object

# %%
pd.to_datetime(test_df['Order_Date'])
# Out:
# C:\Users\PRAVAT PATRA\AppData\Local\Temp\ipykernel_18976\1103262264.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(test_df['Order_Date'])
# 0       2022-03-30
# 1       2022-03-29
# 2       2022-03-10
# 3       2022-04-02
# 4       2022-03-27
#            ...
# 11394   2022-03-27
# 11395   2022-03-11
# 11396   2022-03-11
# 11397   2022-03-06
# 11398   2022-03-24
# Name: Order_Date, Length: 11399, dtype: datetime64[ns]

# %%
"20.22222".isdigit()
# Out:
# False
